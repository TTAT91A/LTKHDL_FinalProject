# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data/DataScientist.csv')
df.head(10)
# Out:
#    Unnamed: 0  index                          Job Title  \
# 0           0      0              Senior Data Scientist
# 1           1      1  Data Scientist, Product Analytics
# 2           2      2               Data Science Manager
# 3           3      3                       Data Analyst
# 4           4      4             Director, Data Science
# 5           5      5                     Data Scientist
# 6           6      6            Quantitative Researcher
# 7           7      7    Quantitative Research Associate
# 8           8      8                       AI Scientist
# 9           9      9            Quantitative Researcher
#
#                 Salary Estimate  \
# 0  $111K-$181K (Glassdoor est.)
# 1  $111K-$181K (Glassdoor est.)
# 2  $111K-$181K (Glassdoor est.)
# 3  $111K-$181K (Glassdoor est.)
# 4  $111K-$181K (Glassdoor est.)
# 5  $111K-$181K (Glassdoor est.)
# 6  $111K-$181K (Glassdoor est.)
# 7  $111K-$181K (Glassdoor est.)
# 8  $111K-$181K (Glassdoor est.)
# 9  $111K-$181K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...     3.5
# 1  At Noom, we use scientifically proven methods ...     4.5
# 2  Decode_M\n\nhttps://www.decode-m.com/\n\nData ...    -1.0
# 3  Sapphire Digital seeks a dynamic and driven mi...     3.4
# 4  Director, Data Science - (200537)\nDescription...     3.4
# 5  Job Brief\n\nThe ideal candidate will have pre...     2.9
# 6  Experience: Entry-level (PhD Program) or Exper...     4.4
# 7  Seeking a quant to work with senior researcher...    -1.0
# 8  Paige is a software company helping pathologis...     5.0
# 9  About the Position\n\n\nAt Jane Street, we con...     4.8
#
#                       Company Name       Location      Headquarters  \
# 0                      Hopper\n3.5   New York, NY  Montreal, Canada
# 1                     Noom US\n4.5   New York, NY      New York, NY
# 2                         Decode_M   New York, NY      New York, NY
# 3            Sapphire Digital\n3.4  Lyndhurst, NJ     Lyndhurst, NJ
# 4  United Entertainment Group\n3.4   New York, NY      New York, NY
# 5               IFG Companies\n2.9   New York, NY      Hartford, CT
# 6                PDT Partners\n4.4   New York, NY      New York, NY
# 7           Enlightenment Research   New York, NY      New York, NY
# 8                       Paige\n5.0   New York, NY      New York, NY
# 9                 Jane Street\n4.8   New York, NY      New York, NY
#
#                      Size  Founded  Type of ownership  \
# 0   501 to 1000 employees     2007  Company - Private
# 1  1001 to 5000 employees     2008  Company - Private
# 2       1 to 50 employees       -1            Unknown
# 3    201 to 500 employees     2019  Company - Private
# 4     51 to 200 employees     2007  Company - Private
# 5    201 to 500 employees     1985  Company - Private
# 6     51 to 200 employees     1993  Company - Private
# 7       1 to 50 employees       -1            Unknown
# 8       1 to 50 employees     2018  Company - Private
# 9   501 to 1000 employees     2000  Company - Private
#
#                                   Industry                  Sector  \
# 0                          Travel Agencies        Travel & Tourism
# 1                Health, Beauty, & Fitness       Consumer Services
# 2                                       -1                      -1
# 3                                 Internet  Information Technology
# 4                  Advertising & Marketing       Business Services
# 5                       Insurance Carriers               Insurance
# 6    Investment Banking & Asset Management                 Finance
# 7                                       -1                      -1
# 8  Enterprise Software & Network Solutions  Information Technology
# 9    Investment Banking & Asset Management                 Finance
#
#                     Revenue                    Competitors Easy Apply
# 0  Unknown / Non-Applicable                             -1         -1
# 1  Unknown / Non-Applicable                             -1         -1
# 2  Unknown / Non-Applicable                             -1       True
# 3  Unknown / Non-Applicable           Zocdoc, Healthgrades         -1
# 4  Unknown / Non-Applicable       BBDO, Grey Group, Droga5         -1
# 5  Unknown / Non-Applicable  Colony Specialty, Markel, RLI         -1
# 6  Unknown / Non-Applicable                             -1         -1
# 7  Unknown / Non-Applicable                             -1       True
# 8  Unknown / Non-Applicable                             -1       True
# 9  Unknown / Non-Applicable                             -1         -1

# %% [markdown]
# ### kích thước data

# %%
df.shape
# Out:
# (3909, 17)

# %% [markdown]
# ### thông tin data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3909 entries, 0 to 3908
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         3909 non-null   int64
#  1   index              3909 non-null   int64
#  2   Job Title          3909 non-null   object
#  3   Salary Estimate    3909 non-null   object
#  4   Job Description    3909 non-null   object
#  5   Rating             3909 non-null   float64
#  6   Company Name       3909 non-null   object
#  7   Location           3909 non-null   object
#  8   Headquarters       3909 non-null   object
#  9   Size               3909 non-null   object
#  10  Founded            3909 non-null   int64
#  11  Type of ownership  3909 non-null   object
#  12  Industry           3909 non-null   object
#  13  Sector             3909 non-null   object
#  14  Revenue            3909 non-null   object
#  15  Competitors        3909 non-null   object
#  16  Easy Apply         3909 non-null   object
# dtypes: float64(1), int64(3), object(13)
# memory usage: 519.3+ KB

# %% [markdown]
# ### Xóa cột Unnamed: 0

# %%
df = df.drop('Unnamed: 0',axis=1)
df.tail()
# Out:
#       index                                          Job Title  \
# 3904   4375                                  AWS Data Engineer
# 3905   4376                              Data Analyst â Junior
# 3906   4377                   Security Analytics Data Engineer
# 3907   4378                   Security Analytics Data Engineer
# 3908   4379  Patient Safety Physician or Safety Scientist -...
#
#                   Salary Estimate  \
# 3904  $55K-$112K (Glassdoor est.)
# 3905  $55K-$112K (Glassdoor est.)
# 3906  $55K-$112K (Glassdoor est.)
# 3907  $55K-$112K (Glassdoor est.)
# 3908  $55K-$112K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 3904  About Us\n\nTachyon Technologies is a Digital ...     4.4
# 3905  Job description\nInterpret data, analyze resul...     5.0
# 3906  Job DescriptionThe Security Analytics Data Eng...     3.8
# 3907  The Security Analytics Data Engineer will inte...     4.0
# 3908  Help us transform patients' lives.\nAt UCB, we...     3.7
#
#                                Company Name      Location      Headquarters  \
# 3904              Tachyon Technologies\n4.4    Dublin, OH        Irving, TX
# 3905  Staffigo Technical Services, LLC\n5.0  Columbus, OH     Woodridge, IL
# 3906                    PDS Tech, Inc.\n3.8    Dublin, OH        Irving, TX
# 3907        Data Resource Technologies\n4.0    Dublin, OH         Omaha, NE
# 3908                               UCB\n3.7    Slough, OH  Brussel, Belgium
#
#                          Size  Founded  Type of ownership  \
# 3904     201 to 500 employees     2011  Company - Private
# 3905      51 to 200 employees     2008  Company - Private
# 3906  5001 to 10000 employees     1977  Company - Private
# 3907        1 to 50 employees       -1  Company - Private
# 3908  5001 to 10000 employees       -1   Company - Public
#
#                        Industry                     Sector  \
# 3904                IT Services     Information Technology
# 3905                IT Services     Information Technology
# 3906     Staffing & Outsourcing          Business Services
# 3907                 Accounting         Accounting & Legal
# 3908  Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
#
#                          Revenue Competitors Easy Apply
# 3904    $10 to $25 million (USD)          -1         -1
# 3905   $50 to $100 million (USD)          -1         -1
# 3906  $100 to $500 million (USD)          -1         -1
# 3907  Less than $1 million (USD)          -1         -1
# 3908      $2 to $5 billion (USD)      AbbVie         -1

# %% [markdown]
# ### Thay thế giá trị -1 trong cột Easy Apply bằng giá trị boolean False

# %%
df['Easy Apply'] = df['Easy Apply'].fillna(False).astype(bool)

# %% [markdown]
# ## 1. Data Cleaning

# %% [markdown]
# ### Chuyển các giá trị -1 thành 'nan'

# %%
df.replace(['-1'], [np.nan], inplace=True)
df.replace(['-1.0'], [np.nan], inplace=True)
df.replace([-1], [np.nan], inplace=True)
df.isnull().sum()
# Out:
# index                   0
# Job Title               0
# Salary Estimate         0
# Job Description         0
# Rating                409
# Company Name            0
# Location                0
# Headquarters          240
# Size                  229
# Founded               977
# Type of ownership     229
# Industry              546
# Sector                546
# Revenue               229
# Competitors          2760
# Easy Apply              0
# dtype: int64

# %% [markdown]
# ## Tách cột Salary Estimate thành 2 cột Minimum Salary và Maximum Salary

# %%
df_salary = df['Salary Estimate'].str.split("-",expand=True,)

minimum_salary = df_salary[0]
minimum_salary = minimum_salary.str.replace('K',' ')


maximum_salary = df_salary[1].str.replace('(Glassdoor est.)', ' ')
maximum_salary = maximum_salary.str.replace('(', ' ')
maximum_salary = maximum_salary.str.replace(')', ' ')
maximum_salary = maximum_salary.str.replace('K', ' ')
maximum_salary = maximum_salary.str.replace('Employer est.', ' ')
maximum_salary = maximum_salary.str.replace('Per Hour', ' ')

maximum_salary = maximum_salary.str.replace('$', ' ').fillna(0).astype(int)
minimum_salary = minimum_salary.str.replace('$', ' ').fillna(0).astype(int)

df['Minimum Salary'] = minimum_salary
df['Maximum Salary'] = maximum_salary

df.drop('Salary Estimate',axis = 1,inplace = True)
df['Company Name'] = df['Company Name'].str.replace('\n.*', ' ')
df['Est_Salary']= (df['Minimum Salary']+df['Maximum Salary'])/2

# %% [markdown]
# ## Tách cột Location và HeadQuarters thành City và Nation (or State)

# %%
Location = df['Location'].str.split(",",expand=True,)
Location_City = Location[0]
Location_State = Location[1]
df['Location City'] = Location_City
df['Location State'] = Location_State
df.drop('Location',axis = 1, inplace = True)

HQ = df['Headquarters'].str.split(",",expand=True)
Headquarters_City = HQ[0]
Headquarters_State = HQ[1]
df['Headquarters City'] = Headquarters_City
df['Headquarters State (or Nation)'] = Headquarters_State
df.drop('Headquarters',axis = 1, inplace = True)
df
# Out:
#       index                                          Job Title  \
# 0         0                              Senior Data Scientist
# 1         1                  Data Scientist, Product Analytics
# 2         2                               Data Science Manager
# 3         3                                       Data Analyst
# 4         4                             Director, Data Science
# ...     ...                                                ...
# 3904   4375                                  AWS Data Engineer
# 3905   4376                              Data Analyst â Junior
# 3906   4377                   Security Analytics Data Engineer
# 3907   4378                   Security Analytics Data Engineer
# 3908   4379  Patient Safety Physician or Safety Scientist -...
#
#                                         Job Description  Rating  \
# 0     ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...     3.5
# 1     At Noom, we use scientifically proven methods ...     4.5
# 2     Decode_M\n\nhttps://www.decode-m.com/\n\nData ...     NaN
# 3     Sapphire Digital seeks a dynamic and driven mi...     3.4
# 4     Director, Data Science - (200537)\nDescription...     3.4
# ...                                                 ...     ...
# 3904  About Us\n\nTachyon Technologies is a Digital ...     4.4
# 3905  Job description\nInterpret data, analyze resul...     5.0
# 3906  Job DescriptionThe Security Analytics Data Eng...     3.8
# 3907  The Security Analytics Data Engineer will inte...     4.0
# 3908  Help us transform patients' lives.\nAt UCB, we...     3.7
#
#                            Company Name                     Size  Founded  \
# 0                               Hopper     501 to 1000 employees   2007.0
# 1                              Noom US    1001 to 5000 employees   2008.0
# 2                              Decode_M        1 to 50 employees      NaN
# 3                     Sapphire Digital      201 to 500 employees   2019.0
# 4           United Entertainment Group       51 to 200 employees   2007.0
# ...                                 ...                      ...      ...
# 3904              Tachyon Technologies      201 to 500 employees   2011.0
# 3905  Staffigo Technical Services, LLC       51 to 200 employees   2008.0
# 3906                    PDS Tech, Inc.   5001 to 10000 employees   1977.0
# 3907        Data Resource Technologies         1 to 50 employees      NaN
# 3908                               UCB   5001 to 10000 employees      NaN
#
#       Type of ownership                   Industry                     Sector  \
# 0     Company - Private            Travel Agencies           Travel & Tourism
# 1     Company - Private  Health, Beauty, & Fitness          Consumer Services
# 2               Unknown                        NaN                        NaN
# 3     Company - Private                   Internet     Information Technology
# 4     Company - Private    Advertising & Marketing          Business Services
# ...                 ...                        ...                        ...
# 3904  Company - Private                IT Services     Information Technology
# 3905  Company - Private                IT Services     Information Technology
# 3906  Company - Private     Staffing & Outsourcing          Business Services
# 3907  Company - Private                 Accounting         Accounting & Legal
# 3908   Company - Public  Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
#
#                          Revenue               Competitors  Easy Apply  \
# 0       Unknown / Non-Applicable                       NaN        True
# 1       Unknown / Non-Applicable                       NaN        True
# 2       Unknown / Non-Applicable                       NaN        True
# 3       Unknown / Non-Applicable      Zocdoc, Healthgrades        True
# 4       Unknown / Non-Applicable  BBDO, Grey Group, Droga5        True
# ...                          ...                       ...         ...
# 3904    $10 to $25 million (USD)                       NaN        True
# 3905   $50 to $100 million (USD)                       NaN        True
# 3906  $100 to $500 million (USD)                       NaN        True
# 3907  Less than $1 million (USD)                       NaN        True
# 3908      $2 to $5 billion (USD)                    AbbVie        True
#
#       Minimum Salary  Maximum Salary  Est_Salary Location City Location State  \
# 0                111             181       146.0      New York             NY
# 1                111             181       146.0      New York             NY
# 2                111             181       146.0      New York             NY
# 3                111             181       146.0     Lyndhurst             NJ
# 4                111             181       146.0      New York             NY
# ...              ...             ...         ...           ...            ...
# 3904              55             112        83.5        Dublin             OH
# 3905              55             112        83.5      Columbus             OH
# 3906              55             112        83.5        Dublin             OH
# 3907              55             112        83.5        Dublin             OH
# 3908              55             112        83.5        Slough             OH
#
#      Headquarters City Headquarters State (or Nation)
# 0             Montreal                         Canada
# 1             New York                             NY
# 2             New York                             NY
# 3            Lyndhurst                             NJ
# 4             New York                             NY
# ...                ...                            ...
# 3904            Irving                             TX
# 3905         Woodridge                             IL
# 3906            Irving                             TX
# 3907             Omaha                             NE
# 3908           Brussel                        Belgium
#
# [3909 rows x 20 columns]

# %% [markdown]
# ## Tách dữ liệu trong cột Size thành Minimum Size và Maximum Size

# %%
df['Size'] = df['Size'].str.replace('employees', '')
df['Size'] = df['Size'].str.replace('+', 'plus')
df['Size'] = df['Size'].replace('Unknown', None)
df['Size'] = df['Size'].str.replace('10000plus', '10000 to 10001')
size = df['Size'].str.split("to",expand=True)

df['Minimum Size'] = size[0]
df['Maximum Size'] = size[1]
df['Minimum Size'] = pd.to_numeric(df['Minimum Size'])
df['Maximum Size'] = pd.to_numeric(df['Maximum Size'])

# %% [markdown]
# # Question

# %% [markdown]
# ## Mỗi loại công việc nên chọn công ty nào là tốt nhất (Dựa vào Salary và Rating)

# %% [markdown]
# ### Lọc ra từng công việc nên chọn công ty nào là tốt nhất dựa trên tiêu chí Rating và Est_Salary

# %%
job = df[['Job Title','Rating','Est_Salary','Company Name']].groupby(['Job Title']).max()

# %% [markdown]
# ### Loại bỏ cột Rating và Est_Salary ra khởi dataframe và thêm cột Job Title vào dataframe

# %%
x = pd.Series(job['Company Name'].values)
df_company_best_for_EachOfJob = pd.concat([pd.Series(job.index),x], ignore_index = True ,axis = 1)
df_company_best_for_EachOfJob.columns = ['Job Title','Company Name']
df_company_best_for_EachOfJob
# Out:
#                                               Job Title  \
# 0                 #104733 HPC Systems and Data Engineer
# 1     #105054 (CLS) Clinical Lab Scientist - Microbi...
# 2           (CLS) Clinical Lab Scientist - Microbiology
# 3                                 (Data Analyst) BA/BSA
# 4                     (Data Risk Analyst: Data Modeler)
# ...                                                 ...
# 2074                         X-Ray Tomography Scientist
# 2075                                   XYZ Data Analyst
# 2076                        eCommerce Analytics Manager
# 2077                            eDiscovery Data Analyst
# 2078                 machine learning Engineer with AWS
#
#                     Company Name
# 0                  UC San Diego
# 1                  UC San Diego
# 2                  UC San Diego
# 3             InterSources Inc.
# 4      System Soft Technologies
# ...                          ...
# 2074  The Aerospace Corporation
# 2075                      Rosen
# 2076                     Bombas
# 2077                   Servient
# 2078      Jconnect Infotech Inc
#
# [2079 rows x 2 columns]

# %% [markdown]
# ### Nhận xét
# * Data
# * Science

# %% [markdown]
# ## Top 15 lĩnh vực có doanh thu cao nhất

# %% [markdown]
# ### Tách dữ liệu cột Revenue thành Minimum Revenue và Maximum Revenue

# %%
df['Revenue'] = df['Revenue'].replace('Unknown / Non-Applicable', None)
df['Revenue'] = df['Revenue'].str.replace('$', ' ')
df['Revenue'] = df['Revenue'].str.replace('(USD)', ' ')
df['Revenue'] = df['Revenue'].str.replace('(', ' ')
df['Revenue'] = df['Revenue'].str.replace(')', ' ')
df['Revenue'] = df['Revenue'].str.replace(' ', '')

df['Revenue'] = df['Revenue'].str.replace('2to5billion', '2billionto5billion')
df['Revenue'] = df['Revenue'].str.replace('5to10billion ', '5billionto10billion ')
df['Revenue'] = df['Revenue'].replace('million', ' ')
df['Revenue'] = df['Revenue'].replace('10+billion', '10billionto11billion')
df['Revenue'] = df['Revenue'].str.replace('Lessthan1million', '0millionto1million')
df['Revenue'] = df['Revenue'].str.replace('million', ' ')
df['Revenue'] = df['Revenue'].str.replace('billion', '000 ')
df['Revenue'] = df['Revenue'].replace('Unknown / Non-Applicable', np.nan)

Revenue = df['Revenue'].str.split("to",expand=True)

df['Minimum Revenue'] = Revenue[0]
df['Maximum Revenue'] = Revenue[1]
df['Maximum Revenue'] = pd.to_numeric(df['Maximum Revenue'])
df['Minimum Revenue'] = pd.to_numeric(df['Minimum Revenue'])

# %%
df['Minimum Revenue'] = df['Minimum Revenue'].replace([0],[0.1])
df
# Out:
#       index                                          Job Title  \
# 0         0                              Senior Data Scientist
# 1         1                  Data Scientist, Product Analytics
# 2         2                               Data Science Manager
# 3         3                                       Data Analyst
# 4         4                             Director, Data Science
# ...     ...                                                ...
# 3904   4375                                  AWS Data Engineer
# 3905   4376                              Data Analyst â Junior
# 3906   4377                   Security Analytics Data Engineer
# 3907   4378                   Security Analytics Data Engineer
# 3908   4379  Patient Safety Physician or Safety Scientist -...
#
#                                         Job Description  Rating  \
# 0     ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...     3.5
# 1     At Noom, we use scientifically proven methods ...     4.5
# 2     Decode_M\n\nhttps://www.decode-m.com/\n\nData ...     NaN
# 3     Sapphire Digital seeks a dynamic and driven mi...     3.4
# 4     Director, Data Science - (200537)\nDescription...     3.4
# ...                                                 ...     ...
# 3904  About Us\n\nTachyon Technologies is a Digital ...     4.4
# 3905  Job description\nInterpret data, analyze resul...     5.0
# 3906  Job DescriptionThe Security Analytics Data Eng...     3.8
# 3907  The Security Analytics Data Engineer will inte...     4.0
# 3908  Help us transform patients' lives.\nAt UCB, we...     3.7
#
#                            Company Name            Size  Founded  \
# 0                               Hopper     501 to 1000    2007.0
# 1                              Noom US    1001 to 5000    2008.0
# 2                              Decode_M        1 to 50       NaN
# 3                     Sapphire Digital      201 to 500    2019.0
# 4           United Entertainment Group       51 to 200    2007.0
# ...                                 ...             ...      ...
# 3904              Tachyon Technologies      201 to 500    2011.0
# 3905  Staffigo Technical Services, LLC       51 to 200    2008.0
# 3906                    PDS Tech, Inc.   5001 to 10000    1977.0
# 3907        Data Resource Technologies         1 to 50       NaN
# 3908                               UCB   5001 to 10000       NaN
#
#       Type of ownership                   Industry                     Sector  \
# 0     Company - Private            Travel Agencies           Travel & Tourism
# 1     Company - Private  Health, Beauty, & Fitness          Consumer Services
# 2               Unknown                        NaN                        NaN
# 3     Company - Private                   Internet     Information Technology
# 4     Company - Private    Advertising & Marketing          Business Services
# ...                 ...                        ...                        ...
# 3904  Company - Private                IT Services     Information Technology
# 3905  Company - Private                IT Services     Information Technology
# 3906  Company - Private     Staffing & Outsourcing          Business Services
# 3907  Company - Private                 Accounting         Accounting & Legal
# 3908   Company - Public  Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
#
#       ... Maximum Salary Est_Salary  Location City  Location State  \
# 0     ...            181      146.0       New York              NY
# 1     ...            181      146.0       New York              NY
# 2     ...            181      146.0       New York              NY
# 3     ...            181      146.0      Lyndhurst              NJ
# 4     ...            181      146.0       New York              NY
# ...   ...            ...        ...            ...             ...
# 3904  ...            112       83.5         Dublin              OH
# 3905  ...            112       83.5       Columbus              OH
# 3906  ...            112       83.5         Dublin              OH
# 3907  ...            112       83.5         Dublin              OH
# 3908  ...            112       83.5         Slough              OH
#
#       Headquarters City  Headquarters State (or Nation) Minimum Size  \
# 0              Montreal                          Canada        501.0
# 1              New York                              NY       1001.0
# 2              New York                              NY          1.0
# 3             Lyndhurst                              NJ        201.0
# 4              New York                              NY         51.0
# ...                 ...                             ...          ...
# 3904             Irving                              TX        201.0
# 3905          Woodridge                              IL         51.0
# 3906             Irving                              TX       5001.0
# 3907              Omaha                              NE          1.0
# 3908            Brussel                         Belgium       5001.0
#
#      Maximum Size Minimum Revenue Maximum Revenue
# 0          1000.0             NaN             NaN
# 1          5000.0             NaN             NaN
# 2            50.0             NaN             NaN
# 3           500.0             NaN             NaN
# 4           200.0             NaN             NaN
# ...           ...             ...             ...
# 3904        500.0            10.0            25.0
# 3905        200.0            50.0           100.0
# 3906      10000.0           100.0           500.0
# 3907         50.0             0.1             1.0
# 3908      10000.0          2000.0          5000.0
#
# [3909 rows x 24 columns]

# %% [markdown]
# ### Tính doang thu trung bình

# %%
df['Avg Revenue'] = (df['Minimum Revenue']+df['Maximum Revenue'])/2
df
# Out:
#       index                                          Job Title  \
# 0         0                              Senior Data Scientist
# 1         1                  Data Scientist, Product Analytics
# 2         2                               Data Science Manager
# 3         3                                       Data Analyst
# 4         4                             Director, Data Science
# ...     ...                                                ...
# 3904   4375                                  AWS Data Engineer
# 3905   4376                              Data Analyst â Junior
# 3906   4377                   Security Analytics Data Engineer
# 3907   4378                   Security Analytics Data Engineer
# 3908   4379  Patient Safety Physician or Safety Scientist -...
#
#                                         Job Description  Rating  \
# 0     ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...     3.5
# 1     At Noom, we use scientifically proven methods ...     4.5
# 2     Decode_M\n\nhttps://www.decode-m.com/\n\nData ...     NaN
# 3     Sapphire Digital seeks a dynamic and driven mi...     3.4
# 4     Director, Data Science - (200537)\nDescription...     3.4
# ...                                                 ...     ...
# 3904  About Us\n\nTachyon Technologies is a Digital ...     4.4
# 3905  Job description\nInterpret data, analyze resul...     5.0
# 3906  Job DescriptionThe Security Analytics Data Eng...     3.8
# 3907  The Security Analytics Data Engineer will inte...     4.0
# 3908  Help us transform patients' lives.\nAt UCB, we...     3.7
#
#                            Company Name            Size  Founded  \
# 0                               Hopper     501 to 1000    2007.0
# 1                              Noom US    1001 to 5000    2008.0
# 2                              Decode_M        1 to 50       NaN
# 3                     Sapphire Digital      201 to 500    2019.0
# 4           United Entertainment Group       51 to 200    2007.0
# ...                                 ...             ...      ...
# 3904              Tachyon Technologies      201 to 500    2011.0
# 3905  Staffigo Technical Services, LLC       51 to 200    2008.0
# 3906                    PDS Tech, Inc.   5001 to 10000    1977.0
# 3907        Data Resource Technologies         1 to 50       NaN
# 3908                               UCB   5001 to 10000       NaN
#
#       Type of ownership                   Industry                     Sector  \
# 0     Company - Private            Travel Agencies           Travel & Tourism
# 1     Company - Private  Health, Beauty, & Fitness          Consumer Services
# 2               Unknown                        NaN                        NaN
# 3     Company - Private                   Internet     Information Technology
# 4     Company - Private    Advertising & Marketing          Business Services
# ...                 ...                        ...                        ...
# 3904  Company - Private                IT Services     Information Technology
# 3905  Company - Private                IT Services     Information Technology
# 3906  Company - Private     Staffing & Outsourcing          Business Services
# 3907  Company - Private                 Accounting         Accounting & Legal
# 3908   Company - Public  Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
#
#       ... Est_Salary Location City  Location State  Headquarters City  \
# 0     ...      146.0      New York              NY           Montreal
# 1     ...      146.0      New York              NY           New York
# 2     ...      146.0      New York              NY           New York
# 3     ...      146.0     Lyndhurst              NJ          Lyndhurst
# 4     ...      146.0      New York              NY           New York
# ...   ...        ...           ...             ...                ...
# 3904  ...       83.5        Dublin              OH             Irving
# 3905  ...       83.5      Columbus              OH          Woodridge
# 3906  ...       83.5        Dublin              OH             Irving
# 3907  ...       83.5        Dublin              OH              Omaha
# 3908  ...       83.5        Slough              OH            Brussel
#
#       Headquarters State (or Nation)  Minimum Size Maximum Size  \
# 0                             Canada         501.0       1000.0
# 1                                 NY        1001.0       5000.0
# 2                                 NY           1.0         50.0
# 3                                 NJ         201.0        500.0
# 4                                 NY          51.0        200.0
# ...                              ...           ...          ...
# 3904                              TX         201.0        500.0
# 3905                              IL          51.0        200.0
# 3906                              TX        5001.0      10000.0
# 3907                              NE           1.0         50.0
# 3908                         Belgium        5001.0      10000.0
#
#      Minimum Revenue Maximum Revenue Avg Revenue
# 0                NaN             NaN         NaN
# 1                NaN             NaN         NaN
# 2                NaN             NaN         NaN
# 3                NaN             NaN         NaN
# 4                NaN             NaN         NaN
# ...              ...             ...         ...
# 3904            10.0            25.0       17.50
# 3905            50.0           100.0       75.00
# 3906           100.0           500.0      300.00
# 3907             0.1             1.0        0.55
# 3908          2000.0          5000.0     3500.00
#
# [3909 rows x 25 columns]

# %% [markdown]
# ### Tính tổng doanh thu của từng lĩnh vực

# %%
Total_Revenue_Each_Sector = df[['Sector','Avg Revenue']].groupby('Sector').sum()

# %% [markdown]
# ### Vẽ biểu đồ cột thể hiện Top 20 lĩnh vực có tổng doanh thu cao nhất

# %%
plt.rcParams['figure.figsize'] = (15,5)
color = plt.cm.viridis(np.linspace(0,1,20))
top_sector = Total_Revenue_Each_Sector.sort_values(by=['Avg Revenue'],ascending = False).head(20)
top_sector.plot.bar(color=color)
plt.title("Top 20 Sector with the highest Revenue",fontsize=20)
plt.xlabel("Job Title",fontsize=15)
plt.ylabel("Revenue (trillion USD)",fontsize=15);

# %% [markdown]
# ### Nhận xét
# * Có thể thấy ngành IT có doanh thu lớn nhất, cho thấy sự phát triển của ngành này
